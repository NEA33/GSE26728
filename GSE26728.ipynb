# %%
import pandas as pd
import re
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree.export import export_text

# %% [markdown]
# Функция, которая получает начала строк, в которых имеются релевантные данные. sample - информация об испытуемых , series - гены.

# %%
def get_name_sample_series(txt):
    sample = []
    series = []
    i = 0
    try:
        with open(txt, 'r') as f:
            for line in f:
                l = line.split('\t')
                if ('!Sample' in l[0]):
                    sample.append(l[0])
                else:
                    if ('!series' in l[0] or i == 1):
                        i = 1
                        series.append(l[0])
    except IOError:
        print("An IOError has occurred!")
    finally:
        return sample, series[1:-1]

# %% [markdown]
# Преобразование входных данных в словарь

# %%
def dict_data(data):
    dict_data = {}
    for i in range(1,len(data)):
        dict_data[i-1] = re.sub(r"[\'\"\n]","",data[i])
    return dict_data

# %% [markdown]
# Получение DataFrame для sample, series из словарей

# %%
def get_df(txt):
    sample, series = get_name_sample_series(txt)
    try:
        with open(txt, 'r') as f:
            dict_sample = {}
            dict_series = {}
            for line in f:
                l = line.split('\t')
                if (l[0] in sample):
                    dict_sample[re.sub(r"!", "" ,l[0])] = dict_data(l)
                else:
                    if (l[0] in series):
                        dict_series[re.sub(r"\"", "", l[0])] = dict_data(l)
                        
    except IOError:
        print("An IOError has occurred!")
    finally:
        return pd.DataFrame(dict_sample), pd.DataFrame(dict_series)

# %% [markdown]
# Поиск дубликатов в данных по генам

# %%
def find_duplicate(df_series):
    duplicate = []
    dup = pd.DataFrame({'duplicate': df_series.T[1:].duplicated()})
    for i in range(dup.count()[0]):
        if dup.iloc[i].duplicate == True:
            duplicate.append(dup.iloc[i].name)
    return duplicate

# %% [markdown]
# Извлечение номеров испытуемых в выборках control, low_dose, high_dose

# %%
def get_control_low_high(df_sample):
    count_liver = df_sample.Sample_title.count()
    control = []
    low = []
    high = []
    for i in range(count_liver):
        if ('control' in df_sample.Sample_title[i]):
            control.append(i)
        if ('Low' in df_sample.Sample_title[i]):
            low.append(i)
        if ('High' in df_sample.Sample_title[i]):
            high.append(i)
    return control, low, high

# %% [markdown]
# Получение средних значений по каждому гену в выборках control, low_dose, high_dose

# %%
def get_series_mean(df_sample, df_series):
    control, low, high = get_control_low_high(df_sample)
    for col in df_series.columns[1:]:
        df_series[col] = pd.to_numeric(df_series[col])
    s_mean_control = df_series.loc[control].mean(axis=0)
    s_mean_low = df_series.loc[low].mean(axis=0)
    s_mean_high = df_series.loc[high].mean(axis=0)
    return s_mean_control, s_mean_low, s_mean_high

# %% [markdown]
# Построение дерева решений sample1 vs sample2

# %%
def s1_vs_s2 (sample1, sample2):
    clf = DecisionTreeClassifier(random_state=0, max_depth=2)
    X = pd.DataFrame({'s1': sample1, 's2':sample2})
    clf.fit(X.T, [0,1])
    r = export_text(clf)
    return r, X.iloc[int(r.split()[1].split('_')[1])]

# %%
df_sample, df_series = get_df('GSE26728_series_matrix.txt')

# %%
df_sample
# Out:
#               Sample_title Sample_geo_accession          Sample_status  \
# 0       liver_control_rep1            GSM658075  Public on Sep 21 2011
# 1       liver_control_rep2            GSM658076  Public on Sep 21 2011
# 2       liver_control_rep3            GSM658077  Public on Sep 21 2011
# 3       liver_control_rep4            GSM658078  Public on Sep 21 2011
# 4       liver_control_rep5            GSM658079  Public on Sep 21 2011
# 5       liver_control_rep6            GSM658080  Public on Sep 21 2011
# 6    liver_BPALowDose_rep1            GSM658081  Public on Sep 21 2011
# 7    liver_BPALowDose_rep2            GSM658082  Public on Sep 21 2011
# 8    liver_BPALowDose_rep3            GSM658083  Public on Sep 21 2011
# 9    liver_BPALowDose_rep4            GSM658084  Public on Sep 21 2011
# 10   liver_BPALowDose_rep5            GSM658085  Public on Sep 21 2011
# 11   liver_BPALowDose_rep6            GSM658086  Public on Sep 21 2011
# 12  liver_BPAHighDose_rep1            GSM658087  Public on Sep 21 2011
# 13  liver_BPAHighDose_rep2            GSM658088  Public on Sep 21 2011
# 14  liver_BPAHighDose_rep3            GSM658089  Public on Sep 21 2011
# 15  liver_BPAHighDose_rep4            GSM658090  Public on Sep 21 2011
# 16  liver_BPAHighDose_rep5            GSM658091  Public on Sep 21 2011
# 17  liver_BPAHighDose_rep6            GSM658092  Public on Sep 21 2011
#
#    Sample_submission_date Sample_last_update_date Sample_type  \
# 0             Jan 19 2011             Sep 23 2011         RNA
# 1             Jan 19 2011             Sep 23 2011         RNA
# 2             Jan 19 2011             Sep 23 2011         RNA
# 3             Jan 19 2011             Sep 23 2011         RNA
# 4             Jan 19 2011             Sep 23 2011         RNA
# 5             Jan 19 2011             Sep 23 2011         RNA
# 6             Jan 19 2011             Sep 23 2011         RNA
# 7             Jan 19 2011             Sep 23 2011         RNA
# 8             Jan 19 2011             Sep 23 2011         RNA
# 9             Jan 19 2011             Sep 23 2011         RNA
# 10            Jan 19 2011             Sep 23 2011         RNA
# 11            Jan 19 2011             Sep 23 2011         RNA
# 12            Jan 19 2011             Sep 23 2011         RNA
# 13            Jan 19 2011             Sep 23 2011         RNA
# 14            Jan 19 2011             Sep 23 2011         RNA
# 15            Jan 19 2011             Sep 23 2011         RNA
# 16            Jan 19 2011             Sep 23 2011         RNA
# 17            Jan 19 2011             Sep 23 2011         RNA
#
#    Sample_channel_count                             Sample_source_name_ch1  \
# 0                     1                        liver, control, replicate 1
# 1                     1                        liver, control, replicate 2
# 2                     1                        liver, control, replicate 3
# 3                     1                        liver, control, replicate 4
# 4                     1                        liver, control, replicate 5
# 5                     1                        liver, control, replicate 6
# 6                     1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 7                     1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 8                     1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 9                     1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 10                    1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 11                    1  liver, exposed to BPA at 50 µg/Kg/day, replica...
# 12                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
# 13                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
# 14                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
# 15                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
# 16                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
# 17                    1  liver, exposed to BPA at 5000 µg/Kg/day, repli...
#
#    Sample_organism_ch1                   Sample_characteristics_ch1  ...  \
# 0         Mus musculus                           treatment: control  ...
# 1         Mus musculus                           treatment: control  ...
# 2         Mus musculus                           treatment: control  ...
# 3         Mus musculus                           treatment: control  ...
# 4         Mus musculus                           treatment: control  ...
# 5         Mus musculus                           treatment: control  ...
# 6         Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 7         Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 8         Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 9         Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 10        Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 11        Mus musculus    treatment: exposed to BPA at 50 µg/Kg/day  ...
# 12        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
# 13        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
# 14        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
# 15        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
# 16        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
# 17        Mus musculus  treatment: exposed to BPA at 5000 µg/Kg/day  ...
#
#    Sample_contact_name                    Sample_contact_email  \
# 0     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 1     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 2     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 3     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 4     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 5     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 6     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 7     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 8     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 9     Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 10    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 11    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 12    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 13    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 14    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 15    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 16    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
# 17    Pascal,GP,Martin  Pascal.Martin@inra.fr, pascmart@iu.edu
#
#    Sample_contact_laboratory Sample_contact_institute  \
# 0                    ToxAlim                     INRA
# 1                    ToxAlim                     INRA
# 2                    ToxAlim                     INRA
# 3                    ToxAlim                     INRA
# 4                    ToxAlim                     INRA
# 5                    ToxAlim                     INRA
# 6                    ToxAlim                     INRA
# 7                    ToxAlim                     INRA
# 8                    ToxAlim                     INRA
# 9                    ToxAlim                     INRA
# 10                   ToxAlim                     INRA
# 11                   ToxAlim                     INRA
# 12                   ToxAlim                     INRA
# 13                   ToxAlim                     INRA
# 14                   ToxAlim                     INRA
# 15                   ToxAlim                     INRA
# 16                   ToxAlim                     INRA
# 17                   ToxAlim                     INRA
#
#                    Sample_contact_address Sample_contact_city  \
# 0   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 1   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 2   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 3   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 4   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 5   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 6   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 7   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 8   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 9   180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 10  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 11  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 12  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 13  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 14  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 15  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 16  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
# 17  180 chemin de Tournefeuille, BP 93173    Toulouse Cedex 3
#
#    Sample_contact_zip/postal_code Sample_contact_country  \
# 0                           31027                 France
# 1                           31027                 France
# 2                           31027                 France
# 3                           31027                 France
# 4                           31027                 France
# 5                           31027                 France
# 6                           31027                 France
# 7                           31027                 France
# 8                           31027                 France
# 9                           31027                 France
# 10                          31027                 France
# 11                          31027                 France
# 12                          31027                 France
# 13                          31027                 France
# 14                          31027                 France
# 15                          31027                 France
# 16                          31027                 France
# 17                          31027                 France
#
#                             Sample_supplementary_file Sample_data_row_count
# 0   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 1   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 2   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 3   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 4   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 5   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 6   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 7   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 8   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 9   ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 10  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 11  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 12  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 13  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 14  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 15  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 16  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
# 17  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM658n...                 22514
#
# [18 rows x 31 columns]

# %%
df_series
# Out:
#        ID_REF A_51_P100034 A_51_P100063 A_51_P100099 A_51_P100155  \
# 0   GSM658075       12.630        5.828        7.638       10.947
# 1   GSM658076       11.899        6.598        7.635       10.582
# 2   GSM658077       12.393        5.984        7.216       10.406
# 3   GSM658078       12.539        5.986        7.767       11.054
# 4   GSM658079       12.368        6.089        7.516       10.770
# 5   GSM658080       12.361        6.163        7.378       10.402
# 6   GSM658081       12.332        6.384        7.171       10.610
# 7   GSM658082       12.148        6.410        7.558       10.512
# 8   GSM658083       12.032        5.984        7.571       10.492
# 9   GSM658084       11.955        6.158        7.607       10.485
# 10  GSM658085       12.222        6.031        7.523       10.839
# 11  GSM658086       12.202        5.833        7.628       10.535
# 12  GSM658087       12.107        6.441        7.461       10.674
# 13  GSM658088       12.529        7.814        7.321       10.333
# 14  GSM658089       11.838        6.107        7.792       10.622
# 15  GSM658090       12.054        7.017        7.577       10.302
# 16  GSM658091       12.223        5.853        7.412       10.339
# 17  GSM658092       12.343        6.656        7.357       10.572
#
#    A_51_P100174 A_51_P100181 A_51_P100227 A_51_P100246 A_51_P100289  ...  \
# 0         6.632        6.655        8.205        9.787        8.455  ...
# 1         6.089        6.788        8.194        9.590        8.218  ...
# 2         6.012        6.584        8.335        9.846        8.639  ...
# 3         6.190        6.822        8.146        9.733        8.550  ...
# 4         6.260        6.742        8.153        9.027        8.273  ...
# 5         6.131        6.782        8.252        9.852        8.413  ...
# 6         5.993        6.805        8.209        9.363        8.399  ...
# 7         6.274        6.822        8.303        9.166        8.254  ...
# 8         6.002        6.734        8.249        9.492        8.398  ...
# 9         6.011        6.954        8.120        9.592        8.457  ...
# 10        6.124        6.777        8.210        9.039        8.120  ...
# 11        6.062        6.859        8.372        9.624        8.145  ...
# 12        6.375        6.684        8.383        9.458        8.375  ...
# 13        6.087        6.600        8.380        9.081        8.178  ...
# 14        6.152        6.779        8.045        9.301        8.192  ...
# 15        6.202        7.029        8.254        9.361        8.323  ...
# 16        6.209        6.616        8.167        9.407        8.422  ...
# 17        6.172        6.715        8.464        9.346        8.621  ...
#
#    A_52_P995381 A_52_P996032 A_52_P996473 A_52_P99665 A_52_P99670  \
# 0         7.651        8.821        5.901       7.842       7.712
# 1         7.246        8.740        6.098       8.468       7.174
# 2         7.240        8.799        6.142       8.023       7.613
# 3         7.352        8.063        6.114       7.959       7.846
# 4         7.582        8.553        5.856       8.037       8.000
# 5         6.988        8.428        5.963       7.943       7.264
# 6         6.974        7.464        6.103       8.083       7.693
# 7         7.362        8.489        6.444       8.218       6.954
# 8         7.042        8.437        5.413       8.278       7.569
# 9         7.047        8.243        6.283       7.079       8.165
# 10        7.056        8.069        6.108       8.149       6.747
# 11        7.257        7.884        6.215       8.219       6.841
# 12        7.058        8.658        6.205       8.133       7.660
# 13        7.130        7.246        6.275       8.180       7.401
# 14        6.743        8.586        6.366       8.248       6.991
# 15        7.064        7.994        5.957       8.428       7.230
# 16        6.818        8.278        6.123       8.263       6.778
# 17        7.480        7.323        5.649       8.198       7.228
#
#    A_52_P997209 A_52_P997449 A_52_P99807 A_52_P99848 A_52_P99888
# 0         7.734       10.070       8.176       6.951       7.445
# 1         8.105        9.784       7.628       7.187       6.946
# 2         7.841        9.009       7.993       7.154       7.340
# 3         7.631       10.071       7.717       6.452       7.277
# 4         7.893        9.762       6.355       7.582       7.379
# 5         8.232        9.535       6.668       6.585       7.173
# 6         7.570        9.876       6.699       7.758       7.800
# 7         8.146        9.999       7.256       6.601       7.264
# 8         7.550       10.084       6.803       6.838       7.402
# 9         7.820       10.064       8.208       6.869       7.138
# 10        7.648       10.219       8.409       7.436       7.403
# 11        7.675       10.133       7.008       7.073       7.008
# 12        7.763        9.428       6.384       6.741       7.432
# 13        8.154        9.136       8.434       8.453       7.114
# 14        7.703        9.890       6.441       6.870       7.211
# 15        7.878       10.302       6.719       6.755       7.577
# 16        8.058       10.493       6.401       7.348       7.570
# 17        7.989        9.447       7.256       7.659       7.277
#
# [18 rows x 22515 columns]

# %% [markdown]
# Количество исследуемых особей

# %%
df_sample.Sample_title.count()
# Out:
# 18

# %% [markdown]
# Количество исследуемых генов

# %%
len(df_series.columns[1:])
# Out:
# 22514

# %% [markdown]
# Поиск дубликатов в данных по генам

# %%
duplicate = find_duplicate(df_series)

# %% [markdown]
# Количество дубликатов

# %%
len(duplicate)
# Out:
# 30

# %% [markdown]
# Гены дубликаты и их значения

# %%
df_series[duplicate]
# Out:
#    A_51_P120295 A_51_P128973 A_51_P145785 A_51_P160713 A_51_P164504  \
# 0        16.000       16.000       16.000       16.000       16.000
# 1        15.994       15.994       15.994       15.994       15.994
# 2        16.000       16.000       16.000       16.000       16.000
# 3        16.000       16.000       16.000       16.000       16.000
# 4        16.000       16.000       16.000       16.000       16.000
# 5        16.000       16.000       16.000       16.000       16.000
# 6        15.984       15.984       15.984       15.984       15.984
# 7        15.994       15.994       15.994       15.994       15.994
# 8        15.994       15.994       15.994       15.994       15.994
# 9        15.996       15.996       15.996       15.996       15.996
# 10       16.000       16.000       16.000       16.000       16.000
# 11       15.994       15.994       15.994       15.994       15.994
# 12       15.994       15.994       15.994       15.994       15.994
# 13       15.997       15.997       15.997       15.997       15.997
# 14       15.998       15.998       15.998       15.998       15.998
# 15       15.990       15.990       15.990       15.990       15.990
# 16       16.000       16.000       16.000       16.000       16.000
# 17       15.994       15.994       15.994       15.994       15.994
#
#    A_51_P171999 A_51_P182631 A_51_P235945 A_51_P236303 A_51_P287810  ...  \
# 0        16.000       16.000       16.000       16.000       16.000  ...
# 1        15.994       15.994       15.994       15.994       15.994  ...
# 2        16.000       16.000       16.000       16.000       16.000  ...
# 3        16.000       16.000       16.000       16.000       16.000  ...
# 4        16.000       16.000       16.000       16.000       16.000  ...
# 5        16.000       16.000       16.000       16.000       16.000  ...
# 6        15.984       15.984       15.984       15.984       15.984  ...
# 7        15.994       15.994       15.994       15.994       15.994  ...
# 8        15.994       15.994       15.994       15.994       15.994  ...
# 9        15.996       15.996       15.996       15.996       15.996  ...
# 10       16.000       16.000       16.000       16.000       16.000  ...
# 11       15.994       15.994       15.994       15.994       15.994  ...
# 12       15.994       15.994       15.994       15.994       15.994  ...
# 13       15.997       15.997       15.997       15.997       15.997  ...
# 14       15.998       15.998       15.998       15.998       15.998  ...
# 15       15.990       15.990       15.990       15.990       15.990  ...
# 16       16.000       16.000       16.000       16.000       16.000  ...
# 17       15.994       15.994       15.994       15.994       15.994  ...
#
#    A_51_P428483 A_51_P461703 A_51_P474701 A_51_P486046 A_52_P232508  \
# 0        16.000       16.000       16.000       16.000       15.994
# 1        15.994       15.994       15.994       15.994       15.994
# 2        16.000       16.000       16.000       16.000       16.000
# 3        16.000       16.000       16.000       16.000       16.000
# 4        16.000       16.000       16.000       16.000       16.000
# 5        16.000       16.000       16.000       16.000       16.000
# 6        15.984       15.984       15.984       15.984       15.984
# 7        15.994       15.994       15.994       15.994       15.994
# 8        15.994       15.994       15.994       15.994       15.994
# 9        15.996       15.996       15.996       15.996       15.996
# 10       16.000       16.000       16.000       16.000       16.000
# 11       15.994       15.994       15.994       15.994       15.994
# 12       15.994       15.994       15.994       15.994       15.994
# 13       15.997       15.997       15.997       15.997       15.997
# 14       15.998       15.998       15.998       15.998       15.998
# 15       15.990       15.990       15.990       15.990       15.990
# 16       16.000       16.000       16.000       16.000       16.000
# 17       15.994       15.994       15.994       15.994       15.994
#
#    A_52_P319093 A_52_P412506 A_52_P436206 A_52_P527944 A_52_P684378
# 0        16.000       16.000       16.000       16.000       16.000
# 1        15.994       15.994       15.994       15.994       15.994
# 2        16.000       16.000       16.000       16.000       16.000
# 3        16.000       16.000       16.000       16.000       16.000
# 4        16.000       16.000       16.000       16.000       16.000
# 5        16.000       16.000       16.000       16.000       16.000
# 6        15.984       15.984       15.984       15.984       15.984
# 7        15.994       15.994       15.994       15.994       15.994
# 8        15.994       15.994       15.994       15.994       15.994
# 9        15.996       15.996       15.996       15.996       15.996
# 10       16.000       16.000       16.000       16.000       16.000
# 11       15.994       15.994       15.994       15.994       15.994
# 12       15.994       15.994       15.994       15.994       15.994
# 13       15.997       15.997       15.997       15.997       15.997
# 14       15.998       15.998       15.998       15.998       15.998
# 15       15.990       15.990       15.990       15.990       15.990
# 16       16.000       16.000       16.000       16.000       16.000
# 17       15.994       15.994       15.994       15.994       15.994
#
# [18 rows x 30 columns]

# %% [markdown]
# Получение усредненных значений по каждой из выборок control, low_dose, high_dose (без удаления дубликатов)

# %%
s_mean_control, s_mean_low, s_mean_high = get_series_mean(df_sample, df_series)

# %%
s_mean_control
# Out:
# A_51_P100034    12.365000
# A_51_P100063     6.108000
# A_51_P100099     7.525000
# A_51_P100155    10.693500
# A_51_P100174     6.219000
#                   ...
# A_52_P997209     7.906000
# A_52_P997449     9.705167
# A_52_P99807      7.422833
# A_52_P99848      6.985167
# A_52_P99888      7.260000
# Length: 22514, dtype: float64

# %%
s_mean_low
# Out:
# A_51_P100034    12.148500
# A_51_P100063     6.133333
# A_51_P100099     7.509667
# A_51_P100155    10.578833
# A_51_P100174     6.077667
#                   ...
# A_52_P997209     7.734833
# A_52_P997449    10.062500
# A_52_P99807      7.397167
# A_52_P99848      7.095833
# A_52_P99888      7.335833
# Length: 22514, dtype: float64

# %%
s_mean_high
# Out:
# A_51_P100034    12.182333
# A_51_P100063     6.648000
# A_51_P100099     7.486667
# A_51_P100155    10.473667
# A_51_P100174     6.199500
#                   ...
# A_52_P997209     7.924167
# A_52_P997449     9.782667
# A_52_P99807      6.939167
# A_52_P99848      7.304333
# A_52_P99888      7.363500
# Length: 22514, dtype: float64

# %% [markdown]
# Дерево решений для классификации control vs low_dose, ген разбиения

# %%
r1, control_vs_low = s1_vs_s2(s_mean_control,s_mean_low)

# %%
print(r1)
print(control_vs_low)
# Out:
# |--- feature_15347 <= 13.86
# |   |--- class: 0
# |--- feature_15347 >  13.86
# |   |--- class: 1
#
# s1    13.796333
# s2    13.924500
# Name: A_52_P315030, dtype: float64

# %% [markdown]
# Дерево решений для классификации control vs high_dose, ген разбиения

# %%
r2, control_vs_high = s1_vs_s2(s_mean_control,s_mean_high)

# %%
print(r2)
print(control_vs_high)
# Out:
# |--- feature_15347 <= 13.83
# |   |--- class: 0
# |--- feature_15347 >  13.83
# |   |--- class: 1
#
# s1    13.796333
# s2    13.872333
# Name: A_52_P315030, dtype: float64
